# %% [markdown]
# # Seaborn Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# data=sns.load_dataset(" ")
# sns.lineplot(x=" ",y=" ",data=data)
# plt.show()

# %%
var=[1,2,3,4,5,6,7]
var_1=[5,6,8,2,6,4,2]
plt.plot(var,var_1)
plt.show()  # matplotlib

# %%
# SEaborn
var=[1,2,3,4,5,6,7]
var_1=[5,6,8,2,6,4,2]
x_1=pd.DataFrame({"var":var,"var_1":var_1})
sns.lineplot(x="var",y="var_1",data=x_1)
# Out:
# <Axes: xlabel='var', ylabel='var_1'>

# %%
# SEaborn
var=[1,2,3,4,5,6,7]
var_1=[5,6,8,2,6,4,2]
x_1=pd.DataFrame({"var":var,"var_1":var_1})
sns.lineplot(x="var",y="var_1",data=x_1)
plt.show() #graph par likhi line chli jaygi

# %%
# SEaborn
var=[1,2,3,4,5,6,7]
var_1=[5,6,8,2,6,4,2]

sns.lineplot(x=var,y=var_1)
plt.show()  # it same by first graph

# %%
y_1=sns.load_dataset("penguins")  #this is data set name
y_1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex")
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",size=10)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex"  )
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent" )
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent",markers=["o",">"])
plt.show()

# %%
y_1=sns.load_dataset("penguins").head(20)  #this is data set name
y_1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent",markers=["o",">"])
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent",markers=["o",">"],dashes=False)
plt.show()

# Doted line change ho jaygi

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent",markers=["o",">"],legend=False)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent",markers=["o",">"],legend="brief")
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=y_1,hue="sex",style="sex",palette="Accent",markers=["o",">"],legend="full")
plt.grid()
plt.title("regex")
plt.show()
