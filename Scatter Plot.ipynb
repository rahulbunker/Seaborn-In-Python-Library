# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# data=sns.load_dataset(" ")
# sns.scatterplot(x=" ",y=" ",data=data)
# plt.show()

# %%
data=sns.load_dataset("penguins")
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data.head(20),hue="sex")
plt.show()

# %%
data=sns.load_dataset("penguins").head(20)

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue="sex",style="sex")
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue="sex",style="sex",size="sex")
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue="sex",style="sex",size="sex"
               ,sizes=(100,400))
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue="sex",style="sex",size="sex"
               ,sizes=(100,400),palette="Accent")
plt.show()

# %%
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue="sex",style="sex",size="sex"
               ,sizes=(100,400),palette="Accent",alpha=0.2)
# color light ho jayga
plt.show()

# %%
m={"Male":"*","Female":"o"}
sns.scatterplot(x="bill_length_mm",y="bill_depth_mm",data=data,hue="sex",style="sex",size="sex"
               ,sizes=(100,400),palette="Accent",markers=m)

plt.show()
