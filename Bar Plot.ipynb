# %% [markdown]
# # Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# df=sns.load_dataset(" ")
# sns.barplot(x=" ",y=" ",data=df)
# plt.show()

# %%
df=sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x=df.island,y=df.bill_length_mm)
# Out:
# <Axes: xlabel='island', ylabel='bill_length_mm'>

# %%
sns.barplot(x=df.island,y=df.bill_length_mm)
plt.show()

# %%
sns.barplot(x="island",y="bill_length_mm",data=df)
plt.show()

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex")
plt.show()

# %%
order_1=["Dream","Torgersen","Biscoe"]
sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",order=order_1)
plt.show()

# %%
order_1=["Dream","Torgersen","Biscoe"]
sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",order=order_1,
           hue_order=["Female","Male"]) # Female phle aajaygi
plt.show()

# %%
order_1=["Dream","Torgersen","Biscoe"]
sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",order=order_1,
           hue_order=["Female","Male"],ci=10)
# uper wala line ki size change hogi
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\1651821021.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 10)` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",order=order_1,

# %%
sns.barplot(x="bill_depth_mm",y="bill_length_mm",data=df,hue="sex",orient="v")
# this is vertical
plt.show()

# %%
sns.barplot(x="bill_depth_mm",y="bill_length_mm",data=df,hue="sex",orient="h")
# this is horizental
plt.show()

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,color="g")

plt.show()

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent")

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\337661589.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent")

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="icefire")

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\235001126.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="icefire")

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",saturation=0.1)

plt.show()
# color blur ho jaynge
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\240981551.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",saturation=0.1)

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y")

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\13296176.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y")
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\13296176.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y")

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y",errwidth=10)

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\2736651162.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y",errwidth=10)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\2736651162.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y",errwidth=10)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\2736651162.py:1: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 10}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="y",errwidth=10)

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="b",capsize=0.5)

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\1845745236.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="b",capsize=0.5)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\1845745236.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'b'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",errcolor="b",capsize=0.5)

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",hue="sex",errcolor="y",dodge=False)

# esem male or female ek dusre par aajaynge
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\3789811431.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",hue="sex",errcolor="y",dodge=False)

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",hue="sex",errcolor="y",dodge=True)
# esme alg alg aaynge
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\718543993.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",hue="sex",errcolor="y",dodge=True)

# %%
sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",hue="sex",errcolor="y",dodge=False,
           alpha=0.1)
# graph ki brightness btata hai

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\1099974034.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,palette="Accent",hue="sex",errcolor="y",dodge=False,

# %%
sns.set(style="dark")  # piche graph ke gridd aajygi
sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",errcolor="y",dodge=False,
        )


plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\2896139024.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",errcolor="y",dodge=False,

# %%
sns.set(style="darkgrid")  # piche graph ke gridd aajygi
sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",errcolor="y",dodge=False,
        )


plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27312\2805657515.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x="island",y="bill_length_mm",data=df,hue="sex",errcolor="y",dodge=False,
